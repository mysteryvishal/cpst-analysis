# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_off = pd.read_csv('off-products.csv', sep='\t')
# Out:
# /var/folders/j2/dgz87tgd2wv8fr4rj3chms_c0000gn/T/ipykernel_76088/2655314760.py:1: DtypeWarning: Columns (0,11,17,23,24,25,31,32,33,34,35,44,46,50,52,56,67,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_off = pd.read_csv('off-products.csv', sep='\t')

# %%
df_off.sample(10)
# Out:
#                   code                                                url  \
# 1127835       27275702  http://world-en.openfoodfacts.org/product/2727...
# 127827   0038445131881  http://world-en.openfoodfacts.org/product/0038...
# 2921357  8436009392549  http://world-en.openfoodfacts.org/product/8436...
# 107271     34856155553  http://world-en.openfoodfacts.org/product/0034...
# 1156755  2952201005903  http://world-en.openfoodfacts.org/product/2952...
# 2950624  8437002393496  http://world-en.openfoodfacts.org/product/8437...
# 2241271  5601227019902  http://world-en.openfoodfacts.org/product/5601...
# 2741848  8052204833559  http://world-en.openfoodfacts.org/product/8052...
# 714081   0803275300543  http://world-en.openfoodfacts.org/product/0803...
# 368226     78742097008  http://world-en.openfoodfacts.org/product/0078...
#
#                  creator   created_t      created_datetime  last_modified_t  \
# 1127835       prepperapp  1685589573  2023-06-01T03:19:33Z       1685589573
# ...

# %%
for i in df_off.columns:
    print(i)
# Out:
# code
# url
# creator
# created_t
# created_datetime
# last_modified_t
# last_modified_datetime
# last_modified_by
# last_updated_t
# last_updated_datetime
# product_name
# abbreviated_product_name
# generic_name
# quantity
# packaging
# packaging_tags
# packaging_en
# packaging_text
# brands
# brands_tags
# categories
# categories_tags
# categories_en
# origins
# origins_tags
# origins_en
# manufacturing_places
# manufacturing_places_tags
# labels
# labels_tags
# labels_en
# emb_codes
# emb_codes_tags
# first_packaging_code_geo
# cities
# cities_tags
# purchase_places
# stores
# countries
# countries_tags
# countries_en
# ingredients_text
# ingredients_tags
# ingredients_analysis_tags
# allergens
# allergens_en
# traces
# traces_tags
# traces_en
# serving_size
# serving_quantity
# no_nutrition_data
# additives_n
# additives
# additives_tags
# additives_en
# nutriscore_score
# nutriscore_grade
# nova_group
# pnns_groups_1
# pnns_groups_2
# food_groups
# food_groups_tags
# ...

# %%
df_off.sample(10)['brands']
# Out:
# 1022868                               NaN
# 1995754                       Uiki & love
# 1001869                             Despi
# 648870                         Farm Fresh
# 1997440                Bon Vegan,Bon Soya
# 138783     Rogue Gold Dairy Inc.,Savencia
# 892038                                NaN
# 1672792                             Yaffa
# 2292629                               NaN
# 36075                           Birds Eye
# Name: brands, dtype: object

# %%
# list of useful columns
[
    'code',
    'url',
    'product_name',
    'quantity',
    'packaging_tags',
    'packaging_en',
    'packaging_text',
    'categories_en',
    'origins_en',
    'labels_en',
    'countries_en',
    'ingredients_tags',
    'ingredients_analysis_tags',
    'allergens_en',
    'traces_en',
    'serving_size',
    'serving_quantity',
    'additives_n',
    'additives_en',
    'nutriscore_score',
    'nutriscore_grade',
    'nova_group',
    'food_groups',
    'food_groups_en',
    'brand_owner',
    'ecoscore_score',
    'ecoscore_grade',
    'nutrient_levels_tags',
    'product_quantity',
    'completeness',
    'main_category',
    'main_category_en',
    'image_url',
    'image_ingredients_url',
    'image_nutrition_url',
    'energy-kcal_100g',
    'fat_100g',
    'saturated-fat_100g',
    'unsaturated-fat_100g',
    'monounsaturated-fat_100g',
    'polyunsaturated-fat_100g',
    'carbohydrates_100g',
    'sugars_100g',
    'added-sugars_100g',
    'fiber_100g',
    'proteins_100g',
    'salt_100g',
    'fruits-vegetables-nuts-estimate-from-ingredients_100g',
    'nutrition-score-uk_100g',
    'glycemic-index_100g',
]
# Out:
# ['code', 'url', 'product_name', 'quantity', 'packaging', 'packaging_tags']

# %%
df_off_non_nan_countries = df_off[df_off['countries'].notna()]

# %%
uk_variations = ['United Kingdom', 'united-kingdom' 'UK', 'uk','Great Britain', 'GB', 'gb', 'Britain']
uk_pattern = '|'.join(uk_variations)
uk_rows = df_off_non_nan_countries[df_off_non_nan_countries['countries'].str.contains(uk_pattern)]
uk_rows
# Out:
#                          code  \
# 206             0000000027083
# 328             0000000050913
# 333             0000000056434
# 419             0000000673358
# 428             0000001071894
# ...                       ...
# 3212968         9990044024128
# 3213023              99920333
# 3213076  99974540135000054001
# 3218312         9999599567067
# 3218416            9999999901
#
#                                                        url          creator  \
# 206      http://world-en.openfoodfacts.org/product/0000...  canieatthis-app
# 328      http://world-en.openfoodfacts.org/product/0000...  canieatthis-app
# 333      http://world-en.openfoodfacts.org/product/0000...  canieatthis-app
# 419      http://world-en.openfoodfacts.org/product/0000...  canieatthis-app
# 428      http://world-en.openfoodfacts.org/product/0000...         bcatelin
# ...                                                    ...              ...
# ...

# %%
uk_rows['countries'].value_counts()
# Out:
# countries
# en:gb                                                                      49989
# en:United Kingdom                                                          33675
# United Kingdom                                                             15611
# gb                                                                          5053
# France,United Kingdom                                                       1398
#                                                                            ...
# Hungary,Romania,United Kingdom                                                 1
# Україна,en:ukraine                                                             1
# Japan, en:ukraine                                                              1
# Lithuania, United Kingdom, United States                                       1
# Australia,Belgium,France,Japan,New Zealand,United Kingdom,United States        1
# Name: count, Length: 705, dtype: int64
